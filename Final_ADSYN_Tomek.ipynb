# %% [markdown]
# #IDA

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from ipywidgets import interact_manual
import plotly.express as px

# %%
from google.colab import drive

drive.mount('/content/drive')

# Replace 'your_file_path' with the actual path to your CSV file in Google Drive
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/stroke.csv')
# Out:
# Mounted at /content/drive

# %%
df.columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.drop('id',axis=1,inplace=True)

# %%
df.shape
# Out:
# (5110, 11)

# %%
df.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  5110.000000   5110.000000    5110.000000        5110.000000
# mean     43.226614      0.097456       0.054012         106.147677
# std      22.612647      0.296607       0.226063          45.283560
# min       0.080000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          77.245000
# 50%      45.000000      0.000000       0.000000          91.885000
# 75%      61.000000      0.000000       0.000000         114.090000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi       stroke
# count  4909.000000  5110.000000
# mean     28.893237     0.048728
# std       7.854067     0.215320
# min      10.300000     0.000000
# 25%      23.500000     0.000000
# 50%      28.100000     0.000000
# 75%      33.100000     0.000000
# max      97.600000     1.000000

# %%
#Checking NA
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %% [markdown]
# #Data Cleaning

# %%
# impute bmi column with mean and print  first ten

df['bmi'] = df['bmi'].fillna(df['bmi'].mean())
df.head(10)
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1  Female  61.0             0              0          Yes  Self-employed
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
# 5    Male  81.0             0              0          Yes        Private
# 6    Male  74.0             1              1          Yes        Private
# 7  Female  69.0             0              0           No        Private
# 8  Female  59.0             0              0          Yes        Private
# 9  Female  78.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level        bmi   smoking_status  stroke
# 0          Urban             228.69  36.600000  formerly smoked       1
# 1          Rural             202.21  28.893237     never smoked       1
# 2          Rural             105.92  32.500000     never smoked       1
# 3          Urban             171.23  34.400000           smokes       1
# 4          Rural             174.12  24.000000     never smoked       1
# 5          Urban             186.21  29.000000  formerly smoked       1
# 6          Rural              70.09  27.400000     never smoked       1
# 7          Urban              94.39  22.800000     never smoked       1
# 8          Rural              76.15  28.893237          Unknown       1
# 9          Urban              58.57  24.200000          Unknown       1

# %%
df.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
numerical = df.select_dtypes(include=['int64','float64']).columns.tolist()
numerical
# Out:
# ['age', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi', 'stroke']

# %%
df.hypertension.value_counts()
# Out:
# hypertension
# 0    4612
# 1     498
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.pie(df.hypertension.value_counts(),labels=['No Hypertension','Hypertension'],autopct='%1.1f%%',
        colors=sns.color_palette('mako',2),explode=(0.3,0.1),shadow=True,textprops={'fontsize':12,'style':'italic'})
# Out:
# ([<matplotlib.patches.Wedge at 0x7892016ae260>,
#   <matplotlib.patches.Wedge at 0x7892016ae1a0>],
#  [Text(-1.3348942113978373, 0.42196853481811436, 'No Hypertension'),
#   Text(1.1441950298751005, -0.3616873423402018, 'Hypertension')],
#  [Text(-0.8581462787557526, 0.2712654866687878, '90.3%'),
#   Text(0.6674471007604752, -0.21098428303178438, '9.7%')])

# %%
df.heart_disease.value_counts()
# Out:
# heart_disease
# 0    4834
# 1     276
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.pie(df.heart_disease.value_counts(),labels=['No Heart disease','Heart disease'],autopct='%1.1f%%',
        colors=sns.color_palette('mako',2),explode=(0.3,0.1),shadow=True,textprops={'fontsize':12,'style':'italic'})
# Out:
# ([<matplotlib.patches.Wedge at 0x7892423f5b40>,
#   <matplotlib.patches.Wedge at 0x7892423f5a80>],
#  [Text(-1.3798936980729009, 0.23641781239723444, 'No Heart disease'),
#   Text(1.182766015061574, -0.2026439084092213, 'Heart disease')],
#  [Text(-0.8870745201897219, 0.1519828793982221, '94.6%'),
#   Text(0.6899468421192514, -0.11820894657204575, '5.4%')])

# %%
plt.figure(figsize=(10,6))
sns.histplot(df.avg_glucose_level,kde=True,bins=30)
# Out:
# <Axes: xlabel='avg_glucose_level', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))
sns.histplot(df.bmi,kde=True,bins=30)
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %% [markdown]
# #Outliers

# %%
plt.figure(figsize=(10,6))
sns.boxplot(df.age)
# Out:
# <Axes: ylabel='age'>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(df.avg_glucose_level)
# Out:
# <Axes: ylabel='avg_glucose_level'>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(df.bmi)
# Out:
# <Axes: ylabel='bmi'>

# %%
# prompt: handle outlier from avg_glucose_level and bmi dont remove it

import numpy as np
def handle_outliers_with_capping(df, column):
  """Handles outliers by capping them at a specified percentile."""
  Q1 = df[column].quantile(0.25)
  Q3 = df[column].quantile(0.75)
  IQR = Q3 - Q1
  lower_bound = Q1 - 1.5 * IQR
  upper_bound = Q3 + 1.5 * IQR

  df[column] = np.where(df[column] < lower_bound, lower_bound, df[column])
  df[column] = np.where(df[column] > upper_bound, upper_bound, df[column])

  return df

df = handle_outliers_with_capping(df, 'avg_glucose_level')
df = handle_outliers_with_capping(df, 'bmi')

# %%
# prompt: print boxplot back

import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
sns.boxplot(df.avg_glucose_level)
plt.figure(figsize=(10,6))
sns.boxplot(df.bmi)
# Out:
# <Axes: ylabel='bmi'>

# %% [markdown]
# # Scalling numeric data

# %%
# prompt: standardize only age, avg_glucose_level and bmi

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# Select the columns to standardize
cols_to_standardize = ['age', 'avg_glucose_level', 'bmi']

# Fit and transform the selected columns
df[cols_to_standardize] = scaler.fit_transform(df[cols_to_standardize])

df.head()
# Out:
#    gender       age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  1.051434             0              1          Yes        Private
# 1  Female  0.786070             0              0          Yes  Self-employed
# 2    Male  1.626390             0              1          Yes        Private
# 3  Female  0.255342             0              0          Yes        Private
# 4  Female  1.582163             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level       bmi   smoking_status  stroke
# 0          Urban           2.058363  1.106633  formerly smoked       1
# 1          Rural           2.058363  0.024107     never smoked       1
# 2          Rural           0.148256  0.530729     never smoked       1
# 3          Urban           2.058363  0.797611           smokes       1
# 4          Rural           2.058363 -0.663218     never smoked       1

# %%
df.describe()
# Out:
#                 age  hypertension  heart_disease  avg_glucose_level  \
# count  5.110000e+03   5110.000000    5110.000000       5.110000e+03
# mean   5.005781e-17      0.097456       0.054012      -3.392807e-16
# std    1.000098e+00      0.296607       0.226063       1.000098e+00
# min   -1.908261e+00      0.000000       0.000000      -1.381335e+00
# 25%   -8.061152e-01      0.000000       0.000000      -7.151503e-01
# 50%    7.843218e-02      0.000000       0.000000      -2.743389e-01
# 75%    7.860701e-01      0.000000       0.000000       3.942550e-01
# max    1.714845e+00      1.000000       1.000000       2.058363e+00
#
#                 bmi       stroke
# count  5.110000e+03  5110.000000
# mean   1.668594e-17     0.048728
# std    1.000098e+00     0.215320
# min   -2.587580e+00     0.000000
# 25%   -6.913112e-01     0.000000
# 50%   -4.517511e-02     0.000000
# 75%    5.728681e-01     0.000000
# max    2.469137e+00     1.000000

# %% [markdown]
# # Scalling discrete data

# %%
categories = df.select_dtypes(include=['object']).columns.tolist()
categories
# Out:
# ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']

# %%
df.gender.value_counts()
# Out:
# gender
# Female    2994
# Male      2115
# Other        1
# Name: count, dtype: int64

# %%
df.drop(df[df.gender == 'Other'].index,inplace=True)
df.reset_index(drop=True,inplace=True)

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="gender", data=df, palette='mako',hue='stroke')
plt.legend(['no stroke','stroke'])

# %%
# prompt: one hot encoding gender to male and female and give value 1 and 0

# Create dummy variables for 'gender'
gender_dummies = pd.get_dummies(df['gender'], prefix='gender')

# Keep only 'Male' and 'Female' columns (assuming you want to encode as 1 and 0)
gender_dummies = gender_dummies[['gender_Male', 'gender_Female']]

# Rename the columns to 'Male' and 'Female'
gender_dummies.rename(columns={'gender_Male': 'Male', 'gender_Female': 'Female'}, inplace=True)

# Concatenate the dummy variables with the original dataframe
df = pd.concat([df, gender_dummies], axis=1)

# Optionally, drop the original 'gender' column
df.drop('gender', axis=1, inplace=True)

# prompt: column male and female turn the true to 1 and false to 0

# Replace True with 1 and False with 0 in 'Male' and 'Female' columns
df['Male'] = df['Male'].astype(int)
df['Female'] = df['Female'].astype(int)

df.head()
# Out:
#         age  hypertension  heart_disease ever_married      work_type  \
# 0  1.051434             0              1          Yes        Private
# 1  0.786070             0              0          Yes  Self-employed
# 2  1.626390             0              1          Yes        Private
# 3  0.255342             0              0          Yes        Private
# 4  1.582163             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level       bmi   smoking_status  stroke  Male  \
# 0          Urban           2.058363  1.106633  formerly smoked       1     1
# 1          Rural           2.058363  0.024107     never smoked       1     0
# 2          Rural           0.148256  0.530729     never smoked       1     1
# 3          Urban           2.058363  0.797611           smokes       1     0
# 4          Rural           2.058363 -0.663218     never smoked       1     0
#
#    Female
# 0       0
# 1       1
# 2       0
# 3       1
# 4       1

# %%
df.ever_married.value_counts()
# Out:
# ever_married
# Yes    3353
# No     1756
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="ever_married", data=df, palette='mako',hue='stroke')
plt.legend(['no stroke','stroke'])

# %%
df.ever_married = df.ever_married.map({'No':0,'Yes':1})

# %%
df.work_type.value_counts()
# Out:
# work_type
# Private          2924
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="work_type", data=df, palette='mako',hue='stroke')
plt.legend(['no stroke','stroke'])

# %%
# prompt: for work_type i want one hot encoding with value 1 and 0 under each column 1 for false and 0 for true

import pandas as pd
# Create dummy variables for 'work_type'
work_type_dummies = pd.get_dummies(df['work_type'], prefix='work_type', dtype=int)

# Concatenate the dummy variables with the original DataFrame
df = pd.concat([df, work_type_dummies], axis=1)

# Drop the original 'work_type' column
df.drop('work_type', axis=1, inplace=True)

# Display the updated DataFrame
df.head()
# Out:
#         age  hypertension  heart_disease  ever_married Residence_type  \
# 0  1.051434             0              1             1          Urban
# 1  0.786070             0              0             1          Rural
# 2  1.626390             0              1             1          Rural
# 3  0.255342             0              0             1          Urban
# 4  1.582163             1              0             1          Rural
#
#    avg_glucose_level       bmi   smoking_status  stroke  Male  Female  \
# 0           2.058363  1.106633  formerly smoked       1     1       0
# 1           2.058363  0.024107     never smoked       1     0       1
# 2           0.148256  0.530729     never smoked       1     1       0
# 3           2.058363  0.797611           smokes       1     0       1
# 4           2.058363 -0.663218     never smoked       1     0       1
#
#    work_type_Govt_job  work_type_Never_worked  work_type_Private  \
# 0                   0                       0                  1
# 1                   0                       0                  0
# 2                   0                       0                  1
# 3                   0                       0                  1
# 4                   0                       0                  0
#
#    work_type_Self-employed  work_type_children
# 0                        0                   0
# 1                        1                   0
# 2                        0                   0
# 3                        0                   0
# 4                        1                   0

# %%
df.Residence_type.value_counts()
# Out:
# Residence_type
# Urban    2596
# Rural    2513
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="Residence_type", data=df, palette='mako',hue='stroke')
plt.legend(['no stroke','stroke'])

# %%
df.Residence_type = df.Residence_type.map({'Urban':0,'Rural':1})

# %%
df.smoking_status.value_counts()
# Out:
# smoking_status
# never smoked       1892
# Unknown            1544
# formerly smoked     884
# smokes              789
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="smoking_status", data=df, palette='mako',hue='stroke')
plt.legend(['no stroke','stroke'])

# %%
# prompt: for smoking_status i want one hot encoding with value 1 and 0 under each column 1 for false and 0 for true

import pandas as pd
# Create dummy variables for 'smoking_status'
smoking_status_dummies = pd.get_dummies(df['smoking_status'], prefix='smoking_status', dtype=int)

# Concatenate the dummy variables with the original DataFrame
df = pd.concat([df, smoking_status_dummies], axis=1)

# Drop the original 'smoking_status' column
df.drop('smoking_status', axis=1, inplace=True)

# Display the updated DataFrame
df.head()
# Out:
#         age  hypertension  heart_disease  ever_married  Residence_type  \
# 0  1.051434             0              1             1               0
# 1  0.786070             0              0             1               1
# 2  1.626390             0              1             1               1
# 3  0.255342             0              0             1               0
# 4  1.582163             1              0             1               1
#
#    avg_glucose_level       bmi  stroke  Male  Female  work_type_Govt_job  \
# 0           2.058363  1.106633       1     1       0                   0
# 1           2.058363  0.024107       1     0       1                   0
# 2           0.148256  0.530729       1     1       0                   0
# 3           2.058363  0.797611       1     0       1                   0
# 4           2.058363 -0.663218       1     0       1                   0
#
#    work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 0                       0                  1                        0
# 1                       0                  0                        1
# 2                       0                  1                        0
# 3                       0                  1                        0
# 4                       0                  0                        1
#
#    work_type_children  smoking_status_Unknown  smoking_status_formerly smoked  \
# 0                   0                       0                               1
# 1                   0                       0                               0
# 2                   0                       0                               0
# 3                   0                       0                               0
# 4                   0                       0                               0
#
#    smoking_status_never smoked  smoking_status_smokes
# 0                            0                      0
# 1                            1                      0
# 2                            1                      0
# 3                            0                      1
# 4                            1                      0

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
# prompt: check for skewness

# Check skewness
for feature in df:
  print(f"Skewness of {feature}: {df[feature].skew()}")
# Out:
# Skewness of age: -0.1374301926292132
# Skewness of hypertension: 2.715026136949753
# Skewness of heart_disease: 3.9467864430646906
# Skewness of ever_married: -0.6583448179224691
# Skewness of Residence_type: 0.03250551429923471
# Skewness of avg_glucose_level: 0.9360521830491011
# Skewness of bmi: 0.4359664055303228
# Skewness of stroke: 4.1928068074994735
# Skewness of Male: 0.34940999903864667
# Skewness of Female: -0.3494099990386462
# Skewness of work_type_Govt_job: 2.219622177275417
# Skewness of work_type_Never_worked: 15.144843094175494
# Skewness of work_type_Private: -0.29245400379529657
# Skewness of work_type_Self-employed: 1.8523009713864769
# Skewness of work_type_children: 2.143534146838143
# Skewness of smoking_status_Unknown: 0.861668935428292
# Skewness of smoking_status_formerly smoked: 1.729276836850054
# Skewness of smoking_status_never smoked: 0.5372263669183076
# Skewness of smoking_status_smokes: 1.9131317548025093

# %%
# prompt: check missing value

df.isnull().sum()
# Out:
# age                               0
# hypertension                      0
# heart_disease                     0
# ever_married                      0
# Residence_type                    0
# avg_glucose_level                 0
# bmi                               0
# stroke                            0
# Male                              0
# Female                            0
# work_type_Govt_job                0
# work_type_Never_worked            0
# work_type_Private                 0
# work_type_Self-employed           0
# work_type_children                0
# smoking_status_Unknown            0
# smoking_status_formerly smoked    0
# smoking_status_never smoked       0
# smoking_status_smokes             0
# dtype: int64

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import ADASYN

from imblearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
import matplotlib.pyplot as plt

# Assume 'df' is your dataframe
x = df.drop('stroke', axis=1)
y = pd.to_numeric(df['stroke'])

# %%
# Setup the resampling pipeline with ADASYN and Tomek Link
from imblearn.under_sampling import TomekLinks
adasyn = ADASYN(random_state=42)
tomek = TomekLinks()
adasyn_tomek = Pipeline([
    ('adasyn', adasyn),  # First apply ADASYN
    ('tomek', tomek)     # Then clean with Tomek Link
])

# Apply the pipeline to resample the entire dataset
X_resampled, y_resampled = adasyn_tomek.fit_resample(x, y)

# Print the class distribution after sampling
print("\nAfter Sampling:")
print(y_resampled.value_counts())
# Out:
# After Sampling:
# stroke
# 0    4778
# 1    4765
# Name: count, dtype: int64

# %%
print("Before Sampling:")
print(y.value_counts())
print("\nAfter Sampling:")

# Print the class distribution after sampling
print("\nAfter Sampling:")
print(y_resampled.value_counts())
# Out:
# Before Sampling:
# stroke
# 0    4860
# 1     249
# Name: count, dtype: int64
#
# After Sampling:
#
# After Sampling:
# stroke
# 0    4778
# 1    4765
# Name: count, dtype: int64

# %%
# Split the data into training and test sets after resampling
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# %% [markdown]
# #Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# Train the Random Forest model
rf_model = RandomForestClassifier(random_state=1234)
rf_model.fit(X_train, y_train)

# Making predictions and evaluating the model on the test set
y_pred = rf_model.predict(X_test)
print("\nClassification Report for Test Data:")
print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred), display_labels=['Class 0', 'Class 1']).plot()

# Plot ROC curve
y_pred_proba = rf_model.predict_proba(X_test)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Random Forest ROC Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# Classification Report for Test Data:
#               precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95       977
#            1       0.92      0.98      0.95       932
#
#     accuracy                           0.95      1909
#    macro avg       0.95      0.95      0.95      1909
# weighted avg       0.95      0.95      0.95      1909

# %% [markdown]
# #Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# Train the Logistic Regression model
log_reg_model = LogisticRegression(max_iter=1000, random_state=1234)
log_reg_model.fit(X_train, y_train)

# Making predictions and evaluating the model on the test set
y_pred = log_reg_model.predict(X_test)
print("\nClassification Report for Test Data:")
print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred), display_labels=['Class 0', 'Class 1']).plot()

# Plot ROC curve
y_pred_proba = log_reg_model.predict_proba(X_test)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Logistic Regression ROC Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# Classification Report for Test Data:
#               precision    recall  f1-score   support
#
#            0       0.84      0.80      0.82       977
#            1       0.80      0.84      0.82       932
#
#     accuracy                           0.82      1909
#    macro avg       0.82      0.82      0.82      1909
# weighted avg       0.82      0.82      0.82      1909

# %% [markdown]
# #KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# Train the KNN model
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(X_train, y_train)

# Making predictions and evaluating the model on the test set
y_pred = knn_model.predict(X_test)
print("\nClassification Report for Test Data:")
print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred), display_labels=['Class 0', 'Class 1']).plot()

# Plot ROC curve
y_pred_proba = knn_model.predict_proba(X_test)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('KNN ROC Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# Classification Report for Test Data:
#               precision    recall  f1-score   support
#
#            0       0.98      0.82      0.89       977
#            1       0.84      0.98      0.90       932
#
#     accuracy                           0.90      1909
#    macro avg       0.91      0.90      0.90      1909
# weighted avg       0.91      0.90      0.90      1909

# %% [markdown]
# #ANN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# Build the ANN model
ann_model = Sequential()
ann_model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
for _ in range(8):
    ann_model.add(Dense(64, activation='relu'))
    ann_model.add(Dropout(0.2))
ann_model.add(Dense(1, activation='sigmoid'))

ann_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the ANN model
history = ann_model.fit(X_train, y_train, validation_split=0.2, epochs=100, batch_size=32, callbacks=[early_stopping], verbose=1)

# Making predictions and evaluating the model on the test set
y_pred = (ann_model.predict(X_test) > 0.5).astype(int)
print("\nClassification Report for Test Data:")
print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred), display_labels=['Class 0', 'Class 1']).plot()

# Plot ROC curve
y_pred_proba = ann_model.predict(X_test).ravel()
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ANN ROC Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 15s 34ms/step - accuracy: 0.6442 - loss: 0.6304 - val_accuracy: 0.8153 - val_loss: 0.4087
# Epoch 2/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8157 - loss: 0.4208 - val_accuracy: 0.8415 - val_loss: 0.3811
# Epoch 3/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8342 - loss: 0.3868 - val_accuracy: 0.8441 - val_loss: 0.3526
# Epoch 4/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8584 - loss: 0.3421 - val_accuracy: 0.8507 - val_loss: 0.3640
# Epoch 5/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8581 - loss: 0.3387 - val_accuracy: 0.8690 - val_loss: 0.3088
# Epoch 6/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8834 - loss: 0.2967 - val_accuracy: 0.8854 - val_loss: 0.2772
# Epoch 7/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8728 - loss: 0.2991 - val_accuracy: 0.8821 - val_loss: 0.2878
# Epoch 8/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8906 - loss: 0.2623 - val_accuracy: 0.8959 - val_loss: 0.2708
# Epoch 9/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9001 - loss: 0.2600 - val_accuracy: 0.8861 - val_loss: 0.2789
# Epoch 10/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9065 - loss: 0.2339 - val_accuracy: 0.8978 - val_loss: 0.2572
# Epoch 11/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9048 - loss: 0.2368 - val_accuracy: 0.9024 - val_loss: 0.2501
# Epoch 12/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9033 - loss: 0.2271 - val_accuracy: 0.9005 - val_loss: 0.2575
# Epoch 13/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9126 - loss: 0.2294 - val_accuracy: 0.8978 - val_loss: 0.2608
# Epoch 14/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9088 - loss: 0.2196 - val_accuracy: 0.8952 - val_loss: 0.2424
# Epoch 15/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9068 - loss: 0.2335 - val_accuracy: 0.8991 - val_loss: 0.2470
# Epoch 16/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9214 - loss: 0.2033 - val_accuracy: 0.9090 - val_loss: 0.2308
# Epoch 17/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9203 - loss: 0.2054 - val_accuracy: 0.8998 - val_loss: 0.2377
# Epoch 18/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9158 - loss: 0.2044 - val_accuracy: 0.9031 - val_loss: 0.2296
# Epoch 19/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9237 - loss: 0.1963 - val_accuracy: 0.8965 - val_loss: 0.2577
# Epoch 20/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9181 - loss: 0.2072 - val_accuracy: 0.8978 - val_loss: 0.2532
# Epoch 21/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9275 - loss: 0.1947 - val_accuracy: 0.9050 - val_loss: 0.2309
# Epoch 22/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9211 - loss: 0.1956 - val_accuracy: 0.8985 - val_loss: 0.2347
# Epoch 23/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9238 - loss: 0.1864 - val_accuracy: 0.9050 - val_loss: 0.2333
# Epoch 24/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9252 - loss: 0.1857 - val_accuracy: 0.9109 - val_loss: 0.2272
# Epoch 25/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9262 - loss: 0.1847 - val_accuracy: 0.9103 - val_loss: 0.2247
# Epoch 26/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9312 - loss: 0.1790 - val_accuracy: 0.9057 - val_loss: 0.2400
# Epoch 27/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9319 - loss: 0.1744 - val_accuracy: 0.9070 - val_loss: 0.2282
# Epoch 28/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9372 - loss: 0.1689 - val_accuracy: 0.9129 - val_loss: 0.2263
# Epoch 29/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9328 - loss: 0.1740 - val_accuracy: 0.9103 - val_loss: 0.2290
# Epoch 30/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9402 - loss: 0.1513 - val_accuracy: 0.9050 - val_loss: 0.2255
# Epoch 31/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9324 - loss: 0.1709 - val_accuracy: 0.9149 - val_loss: 0.2103
# Epoch 32/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9368 - loss: 0.1672 - val_accuracy: 0.9090 - val_loss: 0.2560
# Epoch 33/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9345 - loss: 0.1702 - val_accuracy: 0.9116 - val_loss: 0.2162
# Epoch 34/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9434 - loss: 0.1573 - val_accuracy: 0.9162 - val_loss: 0.2079
# Epoch 35/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9409 - loss: 0.1524 - val_accuracy: 0.9155 - val_loss: 0.2210
# Epoch 36/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9389 - loss: 0.1483 - val_accuracy: 0.9162 - val_loss: 0.2168
# Epoch 37/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9459 - loss: 0.1521 - val_accuracy: 0.9188 - val_loss: 0.2154
# Epoch 38/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9372 - loss: 0.1629 - val_accuracy: 0.9168 - val_loss: 0.2345
# Epoch 39/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9316 - loss: 0.1658 - val_accuracy: 0.9208 - val_loss: 0.2144
# Epoch 40/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9436 - loss: 0.1464 - val_accuracy: 0.9155 - val_loss: 0.2207
# Epoch 41/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9412 - loss: 0.1649 - val_accuracy: 0.9260 - val_loss: 0.2147
# Epoch 42/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9379 - loss: 0.1599 - val_accuracy: 0.9181 - val_loss: 0.2298
# Epoch 43/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9388 - loss: 0.1531 - val_accuracy: 0.9188 - val_loss: 0.2187
# Epoch 44/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9455 - loss: 0.1422 - val_accuracy: 0.9253 - val_loss: 0.2046
# Epoch 45/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9443 - loss: 0.1440 - val_accuracy: 0.9293 - val_loss: 0.2006
# Epoch 46/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9470 - loss: 0.1455 - val_accuracy: 0.9188 - val_loss: 0.2148
# Epoch 47/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9455 - loss: 0.1395 - val_accuracy: 0.9247 - val_loss: 0.2176
# Epoch 48/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9340 - loss: 0.1531 - val_accuracy: 0.9116 - val_loss: 0.2123
# Epoch 49/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9448 - loss: 0.1373 - val_accuracy: 0.9194 - val_loss: 0.2143
# Epoch 50/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9460 - loss: 0.1383 - val_accuracy: 0.9267 - val_loss: 0.2026
# Epoch 51/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9425 - loss: 0.1457 - val_accuracy: 0.9201 - val_loss: 0.2220
# Epoch 52/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9471 - loss: 0.1421 - val_accuracy: 0.9155 - val_loss: 0.2382
# Epoch 53/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9461 - loss: 0.1364 - val_accuracy: 0.9162 - val_loss: 0.2207
# Epoch 54/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9477 - loss: 0.1300 - val_accuracy: 0.9345 - val_loss: 0.1925
# Epoch 55/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9484 - loss: 0.1356 - val_accuracy: 0.9267 - val_loss: 0.2018
# Epoch 56/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9497 - loss: 0.1259 - val_accuracy: 0.9247 - val_loss: 0.2033
# Epoch 57/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9501 - loss: 0.1372 - val_accuracy: 0.9234 - val_loss: 0.2170
# Epoch 58/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9438 - loss: 0.1381 - val_accuracy: 0.9227 - val_loss: 0.2361
# Epoch 59/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9525 - loss: 0.1276 - val_accuracy: 0.9286 - val_loss: 0.2098
# Epoch 60/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9487 - loss: 0.1315 - val_accuracy: 0.9306 - val_loss: 0.2040
# Epoch 61/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9519 - loss: 0.1234 - val_accuracy: 0.9378 - val_loss: 0.1983
# Epoch 62/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9579 - loss: 0.1223 - val_accuracy: 0.9247 - val_loss: 0.2075
# Epoch 63/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9557 - loss: 0.1235 - val_accuracy: 0.9260 - val_loss: 0.2273
# Epoch 64/100
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9503 - loss: 0.1306 - val_accuracy: 0.9247 - val_loss: 0.2674
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
#
# Classification Report for Test Data:
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93       977
#            1       0.90      0.96      0.93       932
#
#     accuracy                           0.93      1909
#    macro avg       0.93      0.93      0.93      1909
# weighted avg       0.93      0.93      0.93      1909
#
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# #XGBoost

# %%
from xgboost import XGBClassifier

# Train the XGBoost model
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=1234)
xgb_model.fit(X_train, y_train)

# Making predictions and evaluating the model on the test set
y_pred = xgb_model.predict(X_test)
print("\nClassification Report for Test Data:")
print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred), display_labels=['Class 0', 'Class 1']).plot()

# Plot ROC curve
y_pred_proba = xgb_model.predict_proba(X_test)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('XGBoost ROC Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [04:09:55] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Classification Report for Test Data:
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94       977
#            1       0.93      0.96      0.94       932
#
#     accuracy                           0.94      1909
#    macro avg       0.94      0.94      0.94      1909
# weighted avg       0.94      0.94      0.94      1909

# %% [markdown]
# #Desicion Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# Train the Decision Tree model
dt_model = DecisionTreeClassifier(random_state=1234)
dt_model.fit(X_train, y_train)

# Making predictions and evaluating the model on the test set
y_pred = dt_model.predict(X_test)
print("\nClassification Report for Test Data:")
print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred), display_labels=['Class 0', 'Class 1']).plot()

# Plot ROC curve
y_pred_proba = dt_model.predict_proba(X_test)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Decision Tree ROC Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# Classification Report for Test Data:
#               precision    recall  f1-score   support
#
#            0       0.91      0.86      0.88       977
#            1       0.86      0.91      0.88       932
#
#     accuracy                           0.88      1909
#    macro avg       0.88      0.88      0.88      1909
# weighted avg       0.88      0.88      0.88      1909

# %% [markdown]
# #SVM

# %%
from sklearn.svm import SVC

# Train the SVM model
svm_model = SVC(probability=True, random_state=1234)
svm_model.fit(X_train, y_train)

# Making predictions and evaluating the model on the test set
y_pred = svm_model.predict(X_test)
print("\nClassification Report for Test Data:")
print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred), display_labels=['Class 0', 'Class 1']).plot()

# Plot ROC curve
y_pred_proba = svm_model.predict_proba(X_test)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('SVM ROC Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# Classification Report for Test Data:
#               precision    recall  f1-score   support
#
#            0       0.93      0.83      0.88       977
#            1       0.84      0.93      0.88       932
#
#     accuracy                           0.88      1909
#    macro avg       0.88      0.88      0.88      1909
# weighted avg       0.88      0.88      0.88      1909
