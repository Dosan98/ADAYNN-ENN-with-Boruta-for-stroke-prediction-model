# %% [markdown]
# #IDA

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from ipywidgets import interact_manual
import plotly.express as px

# %%
from google.colab import drive

drive.mount('/content/drive')

# Replace 'your_file_path' with the actual path to your CSV file in Google Drive
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/stroke.csv')
# Out:
# Mounted at /content/drive

# %%
df.columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.drop('id',axis=1,inplace=True)

# %%
df.shape
# Out:
# (5110, 11)

# %%
df.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  5110.000000   5110.000000    5110.000000        5110.000000
# mean     43.226614      0.097456       0.054012         106.147677
# std      22.612647      0.296607       0.226063          45.283560
# min       0.080000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          77.245000
# 50%      45.000000      0.000000       0.000000          91.885000
# 75%      61.000000      0.000000       0.000000         114.090000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi       stroke
# count  4909.000000  5110.000000
# mean     28.893237     0.048728
# std       7.854067     0.215320
# min      10.300000     0.000000
# 25%      23.500000     0.000000
# 50%      28.100000     0.000000
# 75%      33.100000     0.000000
# max      97.600000     1.000000

# %%
#Checking NA
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %% [markdown]
# #Data Cleaning

# %%
# impute bmi column with mean and print  first ten

df['bmi'] = df['bmi'].fillna(df['bmi'].mean())
df.head(10)
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1  Female  61.0             0              0          Yes  Self-employed
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
# 5    Male  81.0             0              0          Yes        Private
# 6    Male  74.0             1              1          Yes        Private
# 7  Female  69.0             0              0           No        Private
# 8  Female  59.0             0              0          Yes        Private
# 9  Female  78.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level        bmi   smoking_status  stroke
# 0          Urban             228.69  36.600000  formerly smoked       1
# 1          Rural             202.21  28.893237     never smoked       1
# 2          Rural             105.92  32.500000     never smoked       1
# 3          Urban             171.23  34.400000           smokes       1
# 4          Rural             174.12  24.000000     never smoked       1
# 5          Urban             186.21  29.000000  formerly smoked       1
# 6          Rural              70.09  27.400000     never smoked       1
# 7          Urban              94.39  22.800000     never smoked       1
# 8          Rural              76.15  28.893237          Unknown       1
# 9          Urban              58.57  24.200000          Unknown       1

# %%
df.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
numerical = df.select_dtypes(include=['int64','float64']).columns.tolist()
numerical
# Out:
# ['age', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi', 'stroke']

# %%
df.hypertension.value_counts()
# Out:
# hypertension
# 0    4612
# 1     498
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.pie(df.hypertension.value_counts(),labels=['No Hypertension','Hypertension'],autopct='%1.1f%%',
        colors=sns.color_palette('mako',2),explode=(0.3,0.1),shadow=True,textprops={'fontsize':12,'style':'italic'})
# Out:
# ([<matplotlib.patches.Wedge at 0x7c92891cf580>,
#   <matplotlib.patches.Wedge at 0x7c92891cda20>],
#  [Text(-1.3348942113978373, 0.42196853481811436, 'No Hypertension'),
#   Text(1.1441950298751005, -0.3616873423402018, 'Hypertension')],
#  [Text(-0.8581462787557526, 0.2712654866687878, '90.3%'),
#   Text(0.6674471007604752, -0.21098428303178438, '9.7%')])

# %%
df.heart_disease.value_counts()
# Out:
# heart_disease
# 0    4834
# 1     276
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.pie(df.heart_disease.value_counts(),labels=['No Heart disease','Heart disease'],autopct='%1.1f%%',
        colors=sns.color_palette('mako',2),explode=(0.3,0.1),shadow=True,textprops={'fontsize':12,'style':'italic'})
# Out:
# ([<matplotlib.patches.Wedge at 0x7c92875c15d0>,
#   <matplotlib.patches.Wedge at 0x7c92875c1030>],
#  [Text(-1.3798936980729009, 0.23641781239723444, 'No Heart disease'),
#   Text(1.182766015061574, -0.2026439084092213, 'Heart disease')],
#  [Text(-0.8870745201897219, 0.1519828793982221, '94.6%'),
#   Text(0.6899468421192514, -0.11820894657204575, '5.4%')])

# %%
plt.figure(figsize=(10,6))
sns.histplot(df.avg_glucose_level,kde=True,bins=30)
# Out:
# <Axes: xlabel='avg_glucose_level', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))
sns.histplot(df.bmi,kde=True,bins=30)
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %% [markdown]
# #Outliers

# %%
plt.figure(figsize=(10,6))
sns.boxplot(df.age)
# Out:
# <Axes: ylabel='age'>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(df.avg_glucose_level)
# Out:
# <Axes: ylabel='avg_glucose_level'>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(df.bmi)
# Out:
# <Axes: ylabel='bmi'>

# %%
# prompt: handle outlier from avg_glucose_level and bmi dont remove it

import numpy as np
def handle_outliers_with_capping(df, column):
  """Handles outliers by capping them at a specified percentile."""
  Q1 = df[column].quantile(0.25)
  Q3 = df[column].quantile(0.75)
  IQR = Q3 - Q1
  lower_bound = Q1 - 1.5 * IQR
  upper_bound = Q3 + 1.5 * IQR

  df[column] = np.where(df[column] < lower_bound, lower_bound, df[column])
  df[column] = np.where(df[column] > upper_bound, upper_bound, df[column])

  return df

df = handle_outliers_with_capping(df, 'avg_glucose_level')
df = handle_outliers_with_capping(df, 'bmi')

# %%
# prompt: print boxplot back

import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
sns.boxplot(df.avg_glucose_level)
plt.figure(figsize=(10,6))
sns.boxplot(df.bmi)
# Out:
# <Axes: ylabel='bmi'>

# %% [markdown]
# # Scalling numeric data

# %%
# prompt: standardize only age, avg_glucose_level and bmi

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# Select the columns to standardize
cols_to_standardize = ['age', 'avg_glucose_level', 'bmi']

# Fit and transform the selected columns
df[cols_to_standardize] = scaler.fit_transform(df[cols_to_standardize])

df.head()
# Out:
#    gender       age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  1.051434             0              1          Yes        Private
# 1  Female  0.786070             0              0          Yes  Self-employed
# 2    Male  1.626390             0              1          Yes        Private
# 3  Female  0.255342             0              0          Yes        Private
# 4  Female  1.582163             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level       bmi   smoking_status  stroke
# 0          Urban           2.058363  1.106633  formerly smoked       1
# 1          Rural           2.058363  0.024107     never smoked       1
# 2          Rural           0.148256  0.530729     never smoked       1
# 3          Urban           2.058363  0.797611           smokes       1
# 4          Rural           2.058363 -0.663218     never smoked       1

# %%
df.describe()
# Out:
#                 age  hypertension  heart_disease  avg_glucose_level  \
# count  5.110000e+03   5110.000000    5110.000000       5.110000e+03
# mean   5.005781e-17      0.097456       0.054012      -3.392807e-16
# std    1.000098e+00      0.296607       0.226063       1.000098e+00
# min   -1.908261e+00      0.000000       0.000000      -1.381335e+00
# 25%   -8.061152e-01      0.000000       0.000000      -7.151503e-01
# 50%    7.843218e-02      0.000000       0.000000      -2.743389e-01
# 75%    7.860701e-01      0.000000       0.000000       3.942550e-01
# max    1.714845e+00      1.000000       1.000000       2.058363e+00
#
#                 bmi       stroke
# count  5.110000e+03  5110.000000
# mean   1.668594e-17     0.048728
# std    1.000098e+00     0.215320
# min   -2.587580e+00     0.000000
# 25%   -6.913112e-01     0.000000
# 50%   -4.517511e-02     0.000000
# 75%    5.728681e-01     0.000000
# max    2.469137e+00     1.000000

# %% [markdown]
# # Discrete data

# %%
categories = df.select_dtypes(include=['object']).columns.tolist()
categories
# Out:
# ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']

# %%
df.gender.value_counts()
# Out:
# gender
# Female    2994
# Male      2115
# Other        1
# Name: count, dtype: int64

# %%
df.drop(df[df.gender == 'Other'].index,inplace=True)
df.reset_index(drop=True,inplace=True)

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="gender", data=df, palette='mako',hue='stroke')
plt.legend(['no stroke','stroke'])

# %%
# prompt: one hot encoding gender to male and female and give value 1 and 0

# Create dummy variables for 'gender'
gender_dummies = pd.get_dummies(df['gender'], prefix='gender')

# Keep only 'Male' and 'Female' columns (assuming you want to encode as 1 and 0)
gender_dummies = gender_dummies[['gender_Male', 'gender_Female']]

# Rename the columns to 'Male' and 'Female'
gender_dummies.rename(columns={'gender_Male': 'Male', 'gender_Female': 'Female'}, inplace=True)

# Concatenate the dummy variables with the original dataframe
df = pd.concat([df, gender_dummies], axis=1)

# Optionally, drop the original 'gender' column
df.drop('gender', axis=1, inplace=True)

# %%
# prompt: column male and female turn the true to 1 and false to 0

# Replace True with 1 and False with 0 in 'Male' and 'Female' columns
df['Male'] = df['Male'].astype(int)
df['Female'] = df['Female'].astype(int)
df.head()
# Out:
#         age  hypertension  heart_disease ever_married      work_type  \
# 0  1.051434             0              1          Yes        Private
# 1  0.786070             0              0          Yes  Self-employed
# 2  1.626390             0              1          Yes        Private
# 3  0.255342             0              0          Yes        Private
# 4  1.582163             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level       bmi   smoking_status  stroke  Male  \
# 0          Urban           2.058363  1.106633  formerly smoked       1     1
# 1          Rural           2.058363  0.024107     never smoked       1     0
# 2          Rural           0.148256  0.530729     never smoked       1     1
# 3          Urban           2.058363  0.797611           smokes       1     0
# 4          Rural           2.058363 -0.663218     never smoked       1     0
#
#    Female
# 0       0
# 1       1
# 2       0
# 3       1
# 4       1

# %%
df.ever_married.value_counts()
# Out:
# ever_married
# Yes    3353
# No     1756
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="ever_married", data=df, palette='mako',hue='stroke')
plt.legend(['no stroke','stroke'])

# %%
df.ever_married = df.ever_married.map({'No':0,'Yes':1})

# %%
df.work_type.value_counts()
# Out:
# work_type
# Private          2924
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="work_type", data=df, palette='mako',hue='stroke')
plt.legend(['no stroke','stroke'])

# %%
# prompt: for work_type i want one hot encoding with value 1 and 0 under each column 1 for false and 0 for true

import pandas as pd
# Create dummy variables for 'work_type'
work_type_dummies = pd.get_dummies(df['work_type'], prefix='work_type', dtype=int)

# Concatenate the dummy variables with the original DataFrame
df = pd.concat([df, work_type_dummies], axis=1)

# Drop the original 'work_type' column
df.drop('work_type', axis=1, inplace=True)

# Display the updated DataFrame
df.head()
# Out:
#         age  hypertension  heart_disease  ever_married Residence_type  \
# 0  1.051434             0              1             1          Urban
# 1  0.786070             0              0             1          Rural
# 2  1.626390             0              1             1          Rural
# 3  0.255342             0              0             1          Urban
# 4  1.582163             1              0             1          Rural
#
#    avg_glucose_level       bmi   smoking_status  stroke  Male  Female  \
# 0           2.058363  1.106633  formerly smoked       1     1       0
# 1           2.058363  0.024107     never smoked       1     0       1
# 2           0.148256  0.530729     never smoked       1     1       0
# 3           2.058363  0.797611           smokes       1     0       1
# 4           2.058363 -0.663218     never smoked       1     0       1
#
#    work_type_Govt_job  work_type_Never_worked  work_type_Private  \
# 0                   0                       0                  1
# 1                   0                       0                  0
# 2                   0                       0                  1
# 3                   0                       0                  1
# 4                   0                       0                  0
#
#    work_type_Self-employed  work_type_children
# 0                        0                   0
# 1                        1                   0
# 2                        0                   0
# 3                        0                   0
# 4                        1                   0

# %%
df.Residence_type.value_counts()
# Out:
# Residence_type
# Urban    2596
# Rural    2513
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="Residence_type", data=df, palette='mako',hue='stroke')
plt.legend(['no stroke','stroke'])

# %%
df.Residence_type = df.Residence_type.map({'Urban':0,'Rural':1})

# %%
df.smoking_status.value_counts()
# Out:
# smoking_status
# never smoked       1892
# Unknown            1544
# formerly smoked     884
# smokes              789
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="smoking_status", data=df, palette='mako',hue='stroke')
plt.legend(['no stroke','stroke'])

# %%
# prompt: for smoking_status i want one hot encoding with value 1 and 0 under each column 1 for false and 0 for true

import pandas as pd
# Create dummy variables for 'smoking_status'
smoking_status_dummies = pd.get_dummies(df['smoking_status'], prefix='smoking_status', dtype=int)

# Concatenate the dummy variables with the original DataFrame
df = pd.concat([df, smoking_status_dummies], axis=1)

# Drop the original 'smoking_status' column
df.drop('smoking_status', axis=1, inplace=True)

# Display the updated DataFrame
df.head()
# Out:
#         age  hypertension  heart_disease  ever_married  Residence_type  \
# 0  1.051434             0              1             1               0
# 1  0.786070             0              0             1               1
# 2  1.626390             0              1             1               1
# 3  0.255342             0              0             1               0
# 4  1.582163             1              0             1               1
#
#    avg_glucose_level       bmi  stroke  Male  Female  work_type_Govt_job  \
# 0           2.058363  1.106633       1     1       0                   0
# 1           2.058363  0.024107       1     0       1                   0
# 2           0.148256  0.530729       1     1       0                   0
# 3           2.058363  0.797611       1     0       1                   0
# 4           2.058363 -0.663218       1     0       1                   0
#
#    work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 0                       0                  1                        0
# 1                       0                  0                        1
# 2                       0                  1                        0
# 3                       0                  1                        0
# 4                       0                  0                        1
#
#    work_type_children  smoking_status_Unknown  smoking_status_formerly smoked  \
# 0                   0                       0                               1
# 1                   0                       0                               0
# 2                   0                       0                               0
# 3                   0                       0                               0
# 4                   0                       0                               0
#
#    smoking_status_never smoked  smoking_status_smokes
# 0                            0                      0
# 1                            1                      0
# 2                            1                      0
# 3                            0                      1
# 4                            1                      0

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
# prompt: check for skewness

# Check skewness
for feature in df:
  print(f"Skewness of {feature}: {df[feature].skew()}")
# Out:
# Skewness of age: -0.1374301926292132
# Skewness of hypertension: 2.715026136949753
# Skewness of heart_disease: 3.9467864430646906
# Skewness of ever_married: -0.6583448179224691
# Skewness of Residence_type: 0.03250551429923471
# Skewness of avg_glucose_level: 0.9360521830491011
# Skewness of bmi: 0.4359664055303228
# Skewness of stroke: 4.1928068074994735
# Skewness of Male: 0.34940999903864667
# Skewness of Female: -0.3494099990386462
# Skewness of work_type_Govt_job: 2.219622177275417
# Skewness of work_type_Never_worked: 15.144843094175494
# Skewness of work_type_Private: -0.29245400379529657
# Skewness of work_type_Self-employed: 1.8523009713864769
# Skewness of work_type_children: 2.143534146838143
# Skewness of smoking_status_Unknown: 0.861668935428292
# Skewness of smoking_status_formerly smoked: 1.729276836850054
# Skewness of smoking_status_never smoked: 0.5372263669183076
# Skewness of smoking_status_smokes: 1.9131317548025093

# %%
# prompt: check missing value

df.isnull().sum()
# Out:
# age                               0
# hypertension                      0
# heart_disease                     0
# ever_married                      0
# Residence_type                    0
# avg_glucose_level                 0
# bmi                               0
# stroke                            0
# Male                              0
# Female                            0
# work_type_Govt_job                0
# work_type_Never_worked            0
# work_type_Private                 0
# work_type_Self-employed           0
# work_type_children                0
# smoking_status_Unknown            0
# smoking_status_formerly smoked    0
# smoking_status_never smoked       0
# smoking_status_smokes             0
# dtype: int64

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import ADASYN
from imblearn.under_sampling import EditedNearestNeighbours
from imblearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
# !pip install Boruta
from boruta import BorutaPy
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Assume 'df' is your dataframe
x = df.drop('stroke', axis=1)
y = pd.to_numeric(df['stroke'])
# Out:
# Collecting Boruta
#   Downloading Boruta-0.4.3-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.10/dist-packages (from Boruta) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.17.1 in /usr/local/lib/python3.10/dist-packages (from Boruta) (1.5.2)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from Boruta) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.17.1->Boruta) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.17.1->Boruta) (3.5.0)
# Downloading Boruta-0.4.3-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: Boruta
# Successfully installed Boruta-0.4.3

# %%
# Setup the resampling pipeline
adasyn = ADASYN(random_state=42)
enn = EditedNearestNeighbours()
adasyn_enn = Pipeline([
    ('adasyn', adasyn),  # First apply ADASYN
    ('enn', enn)         # Then clean with ENN
])

# Apply the pipeline to resample the entire dataset
X_resampled, y_resampled = adasyn_enn.fit_resample(x, y)

# %%
# prompt: # prompt: show result before and after sampling

# Print the class distribution before sampling
print("Before Sampling:")
print(y.value_counts())

# Print the class distribution after sampling
print("\nAfter Sampling:")
print(y_resampled.value_counts())
# Out:
# Before Sampling:
# stroke
# 0    4860
# 1     249
# Name: count, dtype: int64
#
# After Sampling:
# stroke
# 1    4765
# 0    3848
# Name: count, dtype: int64

# %%
# Feature selection with Boruta
rf_for_boruta = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=5)
boruta_selector = BorutaPy(rf_for_boruta, n_estimators='auto', verbose=2, random_state=1)

# Fit Boruta to the resampled data
boruta_selector.fit(np.array(X_resampled), np.array(y_resampled))

# Filter selected features
selected_features = X_resampled.columns[boruta_selector.support_]
print("Selected Features:")
print(selected_features)


# Get the ranking of features from Boruta
feature_rankings = boruta_selector.ranking_
feature_ranking_df = pd.DataFrame({'Feature': X_resampled.columns, 'Ranking': feature_rankings})

# Display the feature rankings
print("\nFeature Rankings:")
print(feature_ranking_df.sort_values(by='Ranking'))
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	18
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	18
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	18
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	18
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	18
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	18
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	18
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	17
# Tentative: 	1
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	17
# Tentative: 	0
# Rejected: 	1
#
#
# BorutaPy finished running.
#
# Iteration: 	10 / 100
# Confirmed: 	17
# Tentative: 	0
# Rejected: 	1
# Selected Features:
# Index(['age', 'hypertension', 'heart_disease', 'ever_married',
#        'Residence_type', 'avg_glucose_level', 'bmi', 'Male', 'Female',
#        'work_type_Govt_job', 'work_type_Private', 'work_type_Self-employed',
#        'work_type_children', 'smoking_status_Unknown',
#        'smoking_status_formerly smoked', 'smoking_status_never smoked',
#        'smoking_status_smokes'],
#       dtype='object')
#
# Feature Rankings:
#                            Feature  Ranking
# 0                              age        1
# 1                     hypertension        1
# 2                    heart_disease        1
# 3                     ever_married        1
# 4                   Residence_type        1
# 5                avg_glucose_level        1
# 6                              bmi        1
# 7                             Male        1
# 8                           Female        1
# 9               work_type_Govt_job        1
# 11               work_type_Private        1
# 12         work_type_Self-employed        1
# 14          smoking_status_Unknown        1
# 13              work_type_children        1
# 15  smoking_status_formerly smoked        1
# 16     smoking_status_never smoked        1
# 17           smoking_status_smokes        1
# 10          work_type_Never_worked        2

# %%
# Split the data into training and test sets after resampling and feature selection
X_train, X_test, y_train, y_test = train_test_split(X_resampled[selected_features], y_resampled, test_size=0.2, random_state=42)

# %% [markdown]
# #Random Forest

# %%
# Train the RandomForest model
model = RandomForestClassifier(random_state=1234)
model.fit(X_train, y_train)

# Making predictions and evaluating the model on the test set
y_pred = model.predict(X_test)
print("\nClassification Report for Test Data:")
print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred), display_labels=['Class 0', 'Class 1']).plot()

# Plot ROC curve and calculate AUC
y_pred_proba = model.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# Classification Report for Test Data:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97       765
#            1       0.97      0.99      0.98       958
#
#     accuracy                           0.98      1723
#    macro avg       0.98      0.98      0.98      1723
# weighted avg       0.98      0.98      0.98      1723

# %%
# prompt: save this model to google drive

import pickle
from google.colab import drive

drive.mount('/content/drive')

# Assuming your model is named 'model'
model_filename = '/content/drive/My Drive/Colab Notebooks/stroke3_model.pkl'  # Choose a file path in your Google Drive

# Save the model using pickle
with open(model_filename, 'wb') as file:
    pickle.dump(model, file)

print(f"Model saved to: {model_filename}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Model saved to: /content/drive/My Drive/Colab Notebooks/stroke3_model.pkl

# %% [markdown]
# #Logistic regression

# %%
# Import the necessary class from sklearn.linear_model
from sklearn.linear_model import LogisticRegression


# Train the Logistic Regression model
model = LogisticRegression(random_state=1234, max_iter=1000)
model.fit(X_train, y_train)

# Making predictions and evaluating the model on the test set
y_pred = model.predict(X_test)
print("\nClassification Report for Test Data:")
print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred), display_labels=['Class 0', 'Class 1']).plot()

# Plot ROC curve and calculate AUC
y_pred_proba = model.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# Classification Report for Test Data:
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.88       765
#            1       0.89      0.92      0.90       958
#
#     accuracy                           0.89      1723
#    macro avg       0.89      0.89      0.89      1723
# weighted avg       0.89      0.89      0.89      1723

# %% [markdown]
# #KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# Train the KNN model
knn_model = KNeighborsClassifier(n_neighbors=5)  # You can adjust the number of neighbors
knn_model.fit(X_train, y_train)

# Making predictions and evaluating the model on the test set
y_pred = knn_model.predict(X_test)
print("\nClassification Report for Test Data:")
print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred), display_labels=['Class 0', 'Class 1']).plot()

# Plot ROC curve and calculate AUC for KNN
y_pred_proba = knn_model.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# Classification Report for Test Data:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96       765
#            1       0.95      1.00      0.97       958
#
#     accuracy                           0.97      1723
#    macro avg       0.97      0.96      0.97      1723
# weighted avg       0.97      0.97      0.97      1723

# %% [markdown]
# #ANN

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# Build a 10-layer ANN model
ann_model = Sequential()
ann_model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))  # Input layer
for _ in range(8):  # Adding 8 hidden layers
    ann_model.add(Dense(64, activation='relu'))
    ann_model.add(Dropout(0.2))  # Optional: Dropout to prevent overfitting
ann_model.add(Dense(1, activation='sigmoid'))  # Output layer for binary classification

# Compile the model
ann_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = ann_model.fit(X_train, y_train, validation_split=0.2, epochs=100, batch_size=32, callbacks=[early_stopping], verbose=1)

# Making predictions and evaluating the model on the test set
y_pred = (ann_model.predict(X_test) > 0.5).astype(int)  # Convert probabilities to binary predictions

print("\nClassification Report for Test Data:")
print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred), display_labels=['Class 0', 'Class 1']).plot()

# Plot ROC curve and calculate AUC for the ANN model
y_pred_proba = ann_model.predict(X_test).ravel()
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 14s 33ms/step - accuracy: 0.6578 - loss: 0.5797 - val_accuracy: 0.8795 - val_loss: 0.2928
# Epoch 2/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8760 - loss: 0.3129 - val_accuracy: 0.9013 - val_loss: 0.2431
# Epoch 3/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8999 - loss: 0.2718 - val_accuracy: 0.9064 - val_loss: 0.2446
# Epoch 4/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9156 - loss: 0.2211 - val_accuracy: 0.9340 - val_loss: 0.1796
# Epoch 5/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9326 - loss: 0.2001 - val_accuracy: 0.9383 - val_loss: 0.1756
# Epoch 6/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9310 - loss: 0.1764 - val_accuracy: 0.9405 - val_loss: 0.1621
# Epoch 7/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9381 - loss: 0.1750 - val_accuracy: 0.9507 - val_loss: 0.1572
# Epoch 8/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9442 - loss: 0.1657 - val_accuracy: 0.9528 - val_loss: 0.1463
# Epoch 9/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9479 - loss: 0.1437 - val_accuracy: 0.9521 - val_loss: 0.1345
# Epoch 10/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9587 - loss: 0.1229 - val_accuracy: 0.9514 - val_loss: 0.1704
# Epoch 11/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9510 - loss: 0.1252 - val_accuracy: 0.9637 - val_loss: 0.1134
# Epoch 12/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9600 - loss: 0.1144 - val_accuracy: 0.9630 - val_loss: 0.1262
# Epoch 13/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9679 - loss: 0.0954 - val_accuracy: 0.9630 - val_loss: 0.1216
# Epoch 14/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9620 - loss: 0.0952 - val_accuracy: 0.9594 - val_loss: 0.1148
# Epoch 15/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9654 - loss: 0.0937 - val_accuracy: 0.9681 - val_loss: 0.1150
# Epoch 16/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9706 - loss: 0.0834 - val_accuracy: 0.9710 - val_loss: 0.1137
# Epoch 17/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9719 - loss: 0.0839 - val_accuracy: 0.9652 - val_loss: 0.1338
# Epoch 18/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9691 - loss: 0.0855 - val_accuracy: 0.9702 - val_loss: 0.1045
# Epoch 19/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9761 - loss: 0.0804 - val_accuracy: 0.9695 - val_loss: 0.1098
# Epoch 20/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9720 - loss: 0.0765 - val_accuracy: 0.9717 - val_loss: 0.1180
# Epoch 21/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9760 - loss: 0.0757 - val_accuracy: 0.9652 - val_loss: 0.1346
# Epoch 22/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9749 - loss: 0.0736 - val_accuracy: 0.9644 - val_loss: 0.1464
# Epoch 23/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9710 - loss: 0.0833 - val_accuracy: 0.9717 - val_loss: 0.1201
# Epoch 24/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9727 - loss: 0.0692 - val_accuracy: 0.9753 - val_loss: 0.0961
# Epoch 25/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9776 - loss: 0.0689 - val_accuracy: 0.9746 - val_loss: 0.1132
# Epoch 26/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9736 - loss: 0.0699 - val_accuracy: 0.9746 - val_loss: 0.1010
# Epoch 27/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9783 - loss: 0.0608 - val_accuracy: 0.9768 - val_loss: 0.1035
# Epoch 28/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9830 - loss: 0.0473 - val_accuracy: 0.9710 - val_loss: 0.1204
# Epoch 29/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9835 - loss: 0.0460 - val_accuracy: 0.9731 - val_loss: 0.1435
# Epoch 30/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9833 - loss: 0.0480 - val_accuracy: 0.9775 - val_loss: 0.1274
# Epoch 31/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9774 - loss: 0.0645 - val_accuracy: 0.9637 - val_loss: 0.1433
# Epoch 32/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9855 - loss: 0.0473 - val_accuracy: 0.9739 - val_loss: 0.1218
# Epoch 33/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9815 - loss: 0.0492 - val_accuracy: 0.9739 - val_loss: 0.1215
# Epoch 34/100
# 173/173 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9840 - loss: 0.0522 - val_accuracy: 0.9724 - val_loss: 0.1162
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
#
# Classification Report for Test Data:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96       765
#            1       0.96      0.98      0.97       958
#
#     accuracy                           0.96      1723
#    macro avg       0.96      0.96      0.96      1723
# weighted avg       0.96      0.96      0.96      1723
#
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# #XGBoost

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
import matplotlib.pyplot as plt

# Train the XGBoost model
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=1234)
xgb_model.fit(X_train, y_train)

# Making predictions and evaluating the model on the test set
y_pred = xgb_model.predict(X_test)
print("\nClassification Report for Test Data:")
print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred), display_labels=['Class 0', 'Class 1']).plot()

# Plot ROC curve and calculate AUC for the XGBoost model
y_pred_proba = xgb_model.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [05:12:04] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Classification Report for Test Data:
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97       765
#            1       0.96      0.99      0.97       958
#
#     accuracy                           0.97      1723
#    macro avg       0.97      0.97      0.97      1723
# weighted avg       0.97      0.97      0.97      1723

# %% [markdown]
# #Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
import matplotlib.pyplot as plt

# Train the Decision Tree model
dt_model = DecisionTreeClassifier(random_state=1234)
dt_model.fit(X_train, y_train)

# Making predictions and evaluating the model on the test set
y_pred = dt_model.predict(X_test)
print("\nClassification Report for Test Data:")
print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred), display_labels=['Class 0', 'Class 1']).plot()

# Plot ROC curve and calculate AUC for the Decision Tree model
y_pred_proba = dt_model.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# Classification Report for Test Data:
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91       765
#            1       0.92      0.95      0.93       958
#
#     accuracy                           0.92      1723
#    macro avg       0.92      0.92      0.92      1723
# weighted avg       0.92      0.92      0.92      1723

# %% [markdown]
# #SVM

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
import matplotlib.pyplot as plt

# Train the SVM model
svm_model = SVC(probability=True, random_state=1234)
svm_model.fit(X_train, y_train)

# Making predictions and evaluating the model on the test set
y_pred = svm_model.predict(X_test)
print("\nClassification Report for Test Data:")
print(classification_report(y_test, y_pred))
ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred), display_labels=['Class 0', 'Class 1']).plot()

# Plot ROC curve and calculate AUC for the SVM model
y_pred_proba = svm_model.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# Classification Report for Test Data:
#               precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94       765
#            1       0.93      0.98      0.95       958
#
#     accuracy                           0.95      1723
#    macro avg       0.95      0.94      0.95      1723
# weighted avg       0.95      0.95      0.95      1723

# %%
# prompt: hyperparameter tuning svm above with random search with 10 fold

from sklearn.model_selection import RandomizedSearchCV
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold


# Define the parameter grid for random search for SVM
param_grid_svm = {
    'C': [0.1, 1, 10, 100],
    'kernel': ['linear', 'rbf', 'poly'],
    'gamma': ['scale', 'auto'] + list(np.logspace(-3, 3, 7)),
    'degree': [2, 3, 4]  # Only applicable for polynomial kernel
}

# Create an SVM model
svm_model = SVC(probability=True, random_state=42)

# Create the RandomizedSearchCV object with 10-fold cross-validation
random_search_svm = RandomizedSearchCV(
    estimator=svm_model,
    param_distributions=param_grid_svm,
    n_iter=100,
    scoring='accuracy',
    cv=StratifiedKFold(n_splits=10, shuffle=True, random_state=42),  # 10-fold stratified cross-validation
    verbose=2,
    random_state=42,
    n_jobs=-1
)

# Fit the random search to the data
random_search_svm.fit(X_train, y_train)

# Print the best parameters and the corresponding score
print("Best parameters found for SVM: ", random_search_svm.best_params_)
print("Best score for SVM: ", random_search_svm.best_score_)

# Train a model with the best hyperparameters
best_svm_model = random_search_svm.best_estimator_

# You can then evaluate the best model on the test set
y_pred_best_svm = best_svm_model.predict(X_test)
print(classification_report(y_test, y_pred_best_svm))
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-5e50e553b015> in <cell line: 32>()
#      30
#      31 # Fit the random search to the data
# ---> 32 random_search_svm.fit(X_train, y_train)
#      33
#      34 # Print the best parameters and the corresponding score
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, **params)
#    1017                 return results
#    1018
# -> 1019             self._run_search(evaluate_candidates)
#    1020
#    1021             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1958     def _run_search(self, evaluate_candidates):
#    1959         """Search n_iter candidates from param_distributions"""
# -> 1960         evaluate_candidates(
#    1961             ParameterSampler(
#    1962                 self.param_distributions, self.n_iter, random_state=self.random_state
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     963                     )
#     964
# --> 965                 out = parallel(
#     966                     delayed(_fit_and_score)(
#     967                         clone(base_estimator),
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      72             for delayed_func, args, kwargs in iterable
#      73         )
# ---> 74         return super().__call__(iterable_with_config)
#      75
#      76
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    2005         next(output)
#    2006
# -> 2007         return output if self.return_generator else list(output)
#    2008
#    2009     def __repr__(self):
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _get_outputs(self, iterator, pre_dispatch)
#    1648
#    1649             with self._backend.retrieval_context():
# -> 1650                 yield from self._retrieve()
#    1651
#    1652         except GeneratorExit:
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _retrieve(self)
#    1760                 (self._jobs[0].get_status(
#    1761                     timeout=self.timeout) == TASK_PENDING)):
# -> 1762                 time.sleep(0.01)
#    1763                 continue
#    1764
#
# KeyboardInterrupt:
